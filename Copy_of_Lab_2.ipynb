# %% [markdown]
# <a href="https://colab.research.google.com/github/Usmantanoli252/M.USMAN_23122035_LAB-1-6A/blob/main/Copy_of_Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6IoAjCbfwA5Ywghmk7KykH4SSYED13cJ1TJVn60sLghlA ")


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are an AI Software Engineer.

help users with coding problems.

check their code, find errors, and explain how to fix them.

User input:
{user_input}

Make response detailed but easy for students.

User request: {user_input}
Code Detail:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Software Enginering Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = software_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
# Gemini Travel Agent Started (type 'exit' to stop)
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Agent:
#  Hello! I would be happy to help you with your code.
#
# The line of code you shared, **`A = a + b`**, is a very common and fundamental instruction in programming. It is called an **assignment statement**.
#
# While this looks perfect in math class, in programming, it can cause errors depending on how you write the rest of your code. Let’s break down how it works, what errors you might run into, and how to write it correctly!
#
# ---
#
# ### 1. How this code works (The Basics)
# In programming, the computer reads an assignment statement from **right to left**:
# ...
